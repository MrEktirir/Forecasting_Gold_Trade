# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Import

# %%
# In local, I identify the current path of dataset
file_path = r"C:\Users\MRE\Desktop\Data Science & Business\Project\Dataset\aga_bu_son_olsun_artik.csv"

# Then I upload
df = pd.read_csv(file_path, encoding='iso-8859-1')

# %%
df.head(-5)
# Out:
#     TypeCode FreqCode  RefPeriodId  RefYear  RefMonth  Period  ReporterCode  \
# 0          C        A     20170101     2017        52    2017           288
# 1          C        A     20170101     2017        52    2017           288
# 2          C        A     20170101     2017        52    2017           288
# 3          C        A     20170101     2017        52    2017           288
# 4          C        A     20170101     2017        52    2017           288
# ..       ...      ...          ...      ...       ...     ...           ...
# 358        C        A     20230101     2023        52    2023           288
# 359        C        A     20230101     2023        52    2023           288
# 360        C        A     20230101     2023        52    2023           288
# 361        C        A     20230101     2023        52    2023           288
# 362        C        A     20230101     2023        52    2023           288
#
#     ReporterISO ReporterDesc FlowCode  ... IsNetWgtEstimated  GrossWgt  \
# 0           GHA        Ghana        X  ...              True       NaN
# 1           GHA        Ghana        X  ...             False       NaN
# 2           GHA        Ghana        X  ...             False       NaN
# 3           GHA        Ghana        X  ...             False       NaN
# 4           GHA        Ghana        X  ...             False       NaN
# ..          ...          ...      ...  ...               ...       ...
# 358         GHA        Ghana        X  ...             False       0.0
# 359         GHA        Ghana        X  ...             False       0.0
# 360         GHA        Ghana        X  ...              True       0.0
# 361         GHA        Ghana        X  ...             False       0.0
# 362         GHA        Ghana        X  ...             False       0.0
#
#     IsGrossWgtEstimated Cifvalue      Fobvalue  PrimaryValue  \
# 0                 False      NaN  5.858281e+09  5.858281e+09
# 1                 False      NaN  1.103010e+06  1.103010e+06
# 2                 False      NaN  9.274560e+05  9.274560e+05
# 3                 False      NaN  4.926127e+03  4.926127e+03
# 4                 False      NaN  1.940124e+04  1.940124e+04
# ..                  ...      ...           ...           ...
# 358               False      NaN  9.501730e+08  9.501730e+08
# 359               False      NaN  7.642368e+04  7.642368e+04
# 360               False      NaN  1.664745e+09  1.664745e+09
# 361               False      NaN  3.075133e+09  3.075133e+09
# 362               False      NaN  1.667459e+09  1.667459e+09
#
#     LegacyEstimationFlag IsReported IsAggregate  Unnamed: 47
# 0                      0      False        True          NaN
# 1                      0      False        True          NaN
# 2                      0      False        True          NaN
# 3                      0      False        True          NaN
# 4                      0      False        True          NaN
# ..                   ...        ...         ...          ...
# 358                    0      False        True          NaN
# 359                    0      False        True          NaN
# 360                    6      False        True          NaN
# 361                    0      False        True          NaN
# 362                    0      False        True          NaN
#
# [363 rows x 48 columns]
